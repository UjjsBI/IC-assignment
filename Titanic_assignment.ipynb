# %%
#install and then import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading dataset
df=pd.read_csv("/content/sample_data/train.csv")

# %% [markdown]
# 1. What is the distribution of passenger ages on the Titanic?

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# From this chart we have more distribution for the age limit between 20-35

# %% [markdown]
# Steps:
# Check if we have sufficient data.
# if not available create a column
# Get the inference (what chart is saying) from chart

# %% [markdown]
# 2. How does the survival rate vary based on passenger class (Pclass)?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mtitanic = pd.read_csv("/content/sample_data/train.csv")

# %%
mtitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# table
pd.crosstab(mtitanic.Survived,mtitanic.Pclass)
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %% [markdown]
# From the above crosstab visualisation Survival rate in PClass is more than others. Survival rate in PClass 2 is lowest

# %%
#strip plot

sns.stripplot(y= 'Survived', data=mtitanic, jitter=True)
plt.ylabel('Survived ($)')
plt.show()

# %%
#Grouping with stripplot()
sns.stripplot(x='Survived', y='Pclass', data=mtitanic)
plt.ylabel('tPclassip ($)')
plt.show()

# %%
#plt.subplot(1,2,1)
sns.boxplot(x='Survived', y='Pclass', data=mtitanic)
plt.ylabel('tPclassip ($)')

# %%
mtitanic.groupby('Survived')['PassengerId'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x='Survived', y="Age",  data=mtitanic);

# %%
survived = mtitanic.loc[mtitanic['Survived']==1,"Age"].dropna()
sns.distplot(survived)
plt.title("Survived");

# %% [markdown]
# 3. Is there a relationship between the fare paid and the likelihood of survival?

# %%
mtitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
mtitanic[['Survived','Pclass', 'Fare']]
# Out:
#      Survived  Pclass     Fare
# 0           0       3   7.2500
# 1           1       1  71.2833
# 2           1       3   7.9250
# 3           1       1  53.1000
# 4           0       3   8.0500
# ..        ...     ...      ...
# 886         0       2  13.0000
# 887         1       1  30.0000
# 888         0       3  23.4500
# 889         1       1  30.0000
# 890         0       3   7.7500
#
# [891 rows x 3 columns]

# %%
# table
# pd.crosstab(mtitanic.Survived,mtitanic.Fare)
sns.swarmplot(x='Pclass', y='Fare', data=mtitanic, hue = 'Survived')
plt.ylabel('Fare ($)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 21.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 57.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 78.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 29.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Inference : from above chart, Survival rate is more when Fair paid is more i.e PClass=1

# %%
# Density plot
sns.jointplot(x='Fare', y= 'Pclass', data=mtitanic,kind='kde')
plt.show()

# %%
sns.barplot(x="Pclass", y="Survived", data=mtitanic);

# %% [markdown]
# 4. How does the survival rate differ between male and female passengers?

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x="Sex", y="Age", hue="Survived", data=mtitanic);

# %%
sns.barplot(x="Pclass", y="Survived",hue="Sex", data=mtitanic);

# %% [markdown]
# Inference : the survival rate of Female than Male is more in each PClass

# %% [markdown]
# 5. What impact does the number of siblings/spouses (SibSp) or parents/children
# (Parch) aboard have on survival?

# %%
mtitanic[['SibSp','Pclass', 'Survived','Parch']]
# Out:
#      SibSp  Pclass  Survived  Parch
# 0        1       3         0      0
# 1        1       1         1      0
# 2        0       3         1      0
# 3        1       1         1      0
# 4        0       3         0      0
# ..     ...     ...       ...    ...
# 886      0       2         0      0
# 887      0       1         1      0
# 888      1       3         0      2
# 889      0       1         1      0
# 890      0       3         0      0
#
# [891 rows x 4 columns]

# %%
sns.barplot(x="SibSp", y="Survived", data=mtitanic);

# %%
sns.barplot(x="Parch", y="Survived", data=mtitanic);

# %%
sns.pairplot(mtitanic.dropna());

# %% [markdown]
# Inference :

# %% [markdown]
# 6. Are there any significant differences in survival rates among passengers embarked
# from different ports?

# %%
mtitanic[['SibSp','Pclass', 'Survived','Parch','Embarked']]
# Out:
#      SibSp  Pclass  Survived  Parch Embarked
# 0        1       3         0      0        S
# 1        1       1         1      0        C
# 2        0       3         1      0        S
# 3        1       1         1      0        S
# 4        0       3         0      0        S
# ..     ...     ...       ...    ...      ...
# 886      0       2         0      0        S
# 887      0       1         1      0        S
# 888      1       3         0      2        S
# 889      0       1         1      0        C
# 890      0       3         0      0        Q
#
# [891 rows x 5 columns]

# %%
mtitanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
f, ax = plt.subplots(figsize=(7,5))
sns.barplot(x='Embarked', y="Survived",  data=mtitanic);

# %%
# table
pd.crosstab(mtitanic.Embarked,mtitanic.Survived)
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %% [markdown]
# Inference : Survival rate is significantly more those embarked at "S" port than "C" and "Q". It's least for port "Q"
